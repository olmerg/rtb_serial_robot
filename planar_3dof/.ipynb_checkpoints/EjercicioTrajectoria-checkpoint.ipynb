# %%
from roboticstoolbox import DHRobot,RevoluteDH,PrismaticDH
import roboticstoolbox as rtb
import numpy as np
from math import pi
import matplotlib.pyplot as plt
from spatialmath import *

# %%
from Planar3DOF import Planar3DOF
robot=Planar3DOF()
print(robot)
print(robot.links)
# Out:
# ┌───┬───────────┬───────────┬─────────────┬───────────────────┐
# │id │   link    │  parent   │    joint    │        ETS        │
# ├───┼───────────┼───────────┼─────────────┼───────────────────┤
# │ 0 │     world │         - │             │                   │
# │ 1 │ base_link │     world │       fixed │                   │
# │ 2 │    link_1 │ base_link │     joint_1 │ tz(0.05) * Rz(q0) │
# │ 3 │    link_2 │    link_1 │     joint_2 │ tx(0.5) * Rz(q1)  │
# │ 4 │   gripper │    link_2 │     joint_3 │ tx(0.5) * Rz(q2)  │
# │ 5 │      @end │   gripper │ gripper_end │ tx(0.18)          │
# └───┴───────────┴───────────┴─────────────┴───────────────────┘
#
# ┌─────┬─────┬──────┬───────┐
# │name │ q0  │ q1   │ q2    │
# ├─────┼─────┼──────┼───────┤
# │  qz │  0° │  0°  │  0°   │
# │  qr │  0° │  90° │ -90°  │
# │  qs │  0° │  0°  │ -90°  │
# │  qn │  0° │  45° │  180° │
# └─────┴─────┴──────┴───────┘
#
# [ELink(world, ets=), ELink(base_link, ets=, parent=world), ELink(link_1, ets=tz(0.05) * Rz(q), parent=base_link, qlim=[-1.57, 1.57], m=1.0, r=[0.0, 0.0, 0.25]), ELink(link_2, ets=tx(0.5) * Rz(q), parent=link_1, qlim=[-1.57, 1.57], m=1.0, r=[0.0, 0.0, 0.25]), ELink(gripper, ets=tx(0.5) * Rz(q), parent=link_2, qlim=[-1.57, 1.57], m=1.0, r=[0.0, 0.0, 0.1]), ELink(end, ets=tx(0.18), parent=gripper)]

# %%
print(robot.qs)
robot.plot(robot.qs,backend='pyplot',block=False)
# Out:
# [ 0.          0.         -1.57079633]

# %% [markdown]
# ## Fordward and inverse kinematics

# %%
print(robot.qs)
T = robot.fkine(robot.qs)
T
# Out:
# [ 0.          0.         -1.57079633]
# SE3:   0           1           0           1
#       -1           0           0          -0.18
#        0           0           1           0.05
#        0           0           0           1

# %%
sol2=robot.ikine_LM(T,mask=[1,1,1,0,0,0])
print(sol2)
if sol2.success:
    print(robot.fkine(sol2.q))
   
else:
    print("solution not available")
# Out:
# IKsolution(q=array([ 0.03903782, -0.07807886, -1.52752226]), success=True, reason=None, iterations=8, residual=6.539140993047097e-12)
#    0.00423301  0.999991    0           1
#   -0.999991    0.00423301  0          -0.18
#    0           0           1           0.05
#    0           0           0           1

# %% [markdown]
# ## Trayectories by hand

# %%
# perfil velocidades (la de z debe ser zero porque es un robot planar)
pp_d=np.array([0.1,-0.12,0])
#integramos para obtener las posiciones deseadaas 
n=20
Ts=0.1
time=np.linspace(0,n*Ts,n)
p_d=np.zeros((20,len(pp_d)))
p_d[0,:]=np.array([0,0.5,0.05])
for i in range(1,n):
    p_d[i,:]=p_d[i-1,:]+Ts*pp_d
plt.plot(p_d[:,0],p_d[:,1])
plt.xlim([-0.68,0.68])
plt.ylim([-0.68,0.68])
plt.title('movimiento deseado en el plano xy del gripper')
#p_d
# Out:
# Text(0.5, 1.0, 'movimiento deseado en el plano xy del gripper')

# %%
#perfil de orientación
thetap_d=np.array([0.1])
#integramos para obtener las posiciones deseadaas 
theta_d=np.zeros((20,len(thetap_d)))
theta_d[0,:]=np.array([0])
for i in range(1,n):
    theta_d[i,:]=theta_d[i-1,:]+Ts*thetap_d
plt.plot(time,theta_d[:,0]*180/pi)
plt.xlim([0,n*Ts])
plt.ylim([0,360])

plt.title('angulo deseado del gripper con respecto al tiempo')
# Out:
# Text(0.5, 1.0, 'angulo deseado del gripper con respecto al tiempo')

# %%
q_m=np.zeros((n,len(robot.q)))
qp_m=np.zeros((n,len(robot.q)))
for i in range(0,n):
    # transformar a SE3(una rotacion en z + una translación)
    T=SE3.Rz(theta_d[i,0],unit='rad')
    T=SE3(x=p_d[i,0],y=p_d[i,1],z=p_d[i,2])*T   
    
    #try to add initial guess to increase performance
    sol2=robot.ikine_LM(T) 
    #TODO: what to do if no solution?
    if sol2.success:
        q_m[i,:]=sol2.q
        rank=np.linalg.matrix_rank(robot.jacob0(sol2.q))
        #TODO: if the rank is not three there exist a singular position
        if rank==3:
            qp_m[i,:]=np.matmul(np.linalg.pinv(robot.jacob0(sol2.q)[[0,1,-1],:]),pp_d)

# %%
plt.plot(time,q_m*180/pi)
plt.xlim([0,n*Ts])
plt.ylim([-180,180])
plt.legend(['q_0','q_1','q_2'])
plt.title('angulo de los motores con respecto al tiempo')
plt.figure()
plt.plot(time,qp_m*180/pi)
plt.xlim([0,n*Ts])
#plt.ylim([-180,180])
plt.ylabel('deg/s')
plt.xlabel('t(s)')
plt.legend(['q_0','q_1','q_2'])
plt.title('velocidad de los motores con respecto al tiempo')
# Out:
# Text(0.5, 1.0, 'velocidad de los motores con respecto al tiempo')

# %%
env =  rtb.backends.Swift()
env.launch()
env.add(robot)
for i in range(0,n):
        robot.q=q_m[i,:]
        env.step(Ts)
env.remove(robot)
env.close()

# %% [markdown]
# ## Trajectories with toolbox

# %%
T_i=SE3(x=p_d[0,0],y=p_d[0,1],z=p_d[0,2])*SE3.Rz(theta_d[0,0],unit='rad')
T_f=SE3(x=p_d[-1,0],y=p_d[-1,1],z=p_d[-1,2])*SE3.Rz(theta_d[-1,0],unit='rad')
Traj=rtb.tools.trajectory.ctraj(T_i, T_f, 20)
# Out:
# SE3:[0] =
#        1           0           0           0
#        0           1           0           0.5
#        0           0           1           0.05
#        0           0           0           1
#     [1] =
#        0.999999   -0.00118421  0           0.00118421
#        0.00118421  0.999999    0           0.498579
#        0           0           1           0.05
#        0           0           0           1
#     [2] =
#        0.999989   -0.00473682  0           0.00473684
#        0.00473682  0.999989    0           0.494316
#        0           0           1           0.05
#        0           0           0           1
#     [3] =
#        0.999943   -0.0106577   0           0.0106579
#        0.0106577   0.999943    0           0.487211
#        0           0           1           0.05
#        0           0           0           1
#     [4] =   0.999821   -0.0189462   0           0.0189474
#        0.0189462   0.999821    0           0.477263
#        0           0           1           0.05
#        0           0           0           1
#     [5] =   0.999562   -0.0296009   0           0.0296053
#        0.0296009   0.999562    0           0.464474
#        0           0           1           0.05
#        0           0           0           1
#     [6] =   0.999091   -0.0426187   0           0.0426316
#        0.0426187   0.999091    0           0.448842
#        0           0           1           0.05
#        0           0           0           1
#     [7] =   0.998347   -0.0574683   0           0.0575
#        0.0574683   0.998347    0           0.431
#        0           0           1           0.05
#        0           0           0           1
#     [8] =   0.997373   -0.0724365   0           0.0725
#        0.0724365   0.997373    0           0.413
#        0           0           1           0.05
#        0           0           0           1
#     [9] =   0.996174   -0.0873884   0           0.0875
#        0.0873884   0.996174    0           0.395
#        0           0           1           0.05
#        0           0           0           1
#     [10] =   0.994751   -0.102321    0           0.1025
#        0.102321    0.994751    0           0.377
#        0           0           1           0.05
#        0           0           0           1
#     [11] =   0.993105   -0.11723     0           0.1175
#        0.11723     0.993105    0           0.359
#        0           0           1           0.05
#        0           0           0           1
#     [12] =   0.991235   -0.132113    0           0.1325
#        0.132113    0.991235    0           0.341
#        0           0           1           0.05
#        0           0           0           1
#     [13] =   0.989161   -0.146836    0           0.147368
#        0.146836    0.989161    0           0.323158
#        0           0           1           0.05
#        0           0           0           1
#     [14] =   0.987164   -0.159708    0           0.160395
#        0.159708    0.987164    0           0.307526
#        0           0           1           0.05
#        0           0           0           1
#     [15] =   0.985406   -0.17022     0           0.171053
#        0.17022     0.985406    0           0.294737
#        0           0           1           0.05
#        0           0           0           1
#     [16] =   0.983961   -0.178382    0           0.179342
#        0.178382    0.983961    0           0.284789
#        0           0           1           0.05
#        0           0           0           1
#     [17] =   0.982888   -0.184205    0           0.185263
#        0.184205    0.982888    0           0.277684
#        0           0           1           0.05
#        0           0           0           1
#     [18] =   0.982227   -0.187696    0           0.188816
#        0.187696    0.982227    0           0.273421
#        0           0           1           0.05
#        0           0           0           1
#     [19] =   0.982004   -0.188859    0           0.19
#        0.188859    0.982004    0           0.272
#        0           0           1           0.05
#        0           0           0           1

# %%
T[0].printline()
print(T[0].eul())
print(T[0].angvec())
print(UnitQuaternion(T[0].R))
# Out:
# t =     0.19,     0.27,     0.05; rpy/zyx =        0°,        0°,       11°
# [0.   0.   0.19]
# (0.1900000000000001, array([0., 0., 1.]))
#  0.9955 <<  0.0000,  0.0000,  0.0949 >>
